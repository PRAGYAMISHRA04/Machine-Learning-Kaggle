# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('flavors_of_cacao.csv')

# %%
dataset
# Out:
#      Company_name Specific_Bean_Origin   REF  Review_Date Cocoa_Percent  \
# 0        A. Morin          Agua Grande  1876         2016           63%
# 1        A. Morin                Kpime  1676         2015           70%
# 2        A. Morin               Atsane  1676         2015           70%
# 3        A. Morin                Akata  1680         2015           70%
# 4        A. Morin               Quilla  1704         2015           70%
# ...           ...                  ...   ...          ...           ...
# 1790       Zotter                 Peru   647         2011           70%
# 1791       Zotter                Congo   749         2011           65%
# 1792       Zotter         Kerala State   749         2011           65%
# 1793       Zotter         Kerala State   781         2011           62%
# 1794       Zotter   Brazil, Mitzi Blue   486         2010           65%
#
#      Company_Location  Rating  Bean_Type Broad_Bean_Origin
# ...

# %%
dataset.columns
# Out:
# Index(['Company_name', 'Specific_Bean_Origin', 'REF', 'Review_Date',
#        'Cocoa_Percent', 'Company_Location', 'Rating', 'Bean_Type',
#        'Broad_Bean_Origin'],
#       dtype='object')

# %%
Bean_Type=list(dataset.Bean_Type.unique())
dataset.replace((Bean_Type[0]),np.nan,inplace=True)

# %%
data_group_1=dataset.groupby('Company_Location')
for name,group in data_group_1:
    print(name)
    print(group)
# Out:
# Amsterdam
#           Company_name Specific_Bean_Origin   REF  Review_Date Cocoa_Percent  \
# 402   Chocolate Makers         Tres Hombres  1530         2015           75%
# 403   Chocolate Makers   Congo, Gorilla bar  1530         2015           68%
# 404   Chocolate Makers     Peru, Awagum bar  1530         2015           80%
# 1110      Metropolitan        South America  1688         2015           70%
#
#      Company_Location  Rating   Bean_Type   Broad_Bean_Origin
# 402         Amsterdam    3.25  Trinitario  Dominican Republic
# 403         Amsterdam    3.50   Forastero               Congo
# 404         Amsterdam    3.75     Criollo                Peru
# 1110        Amsterdam    3.50  Trinitario       South America
# Argentina
#                          Company_name Specific_Bean_Origin  REF  Review_Date  \
# 440   Compania de Chocolate (Salgado)         Sur del Lago  579         2010
# 441   Compania de Chocolate (Salgado)    Carenero Superior  292         2008
# ...

# %%
Company_Location=list(dataset['Company_Location'].unique())
GROUPS[Company_Location[4]]
# Out:
# Int64Index([31, 900, 1354, 1355], dtype='int64')

# %%
dataset.head()
# Out:
#   Company_name Specific_Bean_Origin   REF  Review_Date Cocoa_Percent  \
# 0     A. Morin          Agua Grande  1876         2016           63%
# 1     A. Morin                Kpime  1676         2015           70%
# 2     A. Morin               Atsane  1676         2015           70%
# 3     A. Morin                Akata  1680         2015           70%
# 4     A. Morin               Quilla  1704         2015           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75       NaN          Sao Tome
# 1           France    2.75       NaN              Togo
# 2           France    3.00       NaN              Togo
# 3           France    3.50       NaN              Togo
# 4           France    3.50       NaN              Peru

# %%
sns.heatmap(dataset.isnull())

# %%
Bean_Type
# Out:
# ['\xa0',
#  'Criollo',
#  'Trinitario',
#  'Forastero (Arriba)',
#  'Forastero',
#  'Forastero (Nacional)',
#  'Criollo, Trinitario',
#  'Criollo (Porcelana)',
#  'Blend',
#  'Trinitario (85% Criollo)',
#  'Forastero (Catongo)',
#  'Forastero (Parazinho)',
#  'Trinitario, Criollo',
#  'CCN51',
#  'Criollo (Ocumare)',
#  'Nacional',
#  'Criollo (Ocumare 61)',
#  'Criollo (Ocumare 77)',
#  'Criollo (Ocumare 67)',
#  'Criollo (Wild)',
#  'Beniano',
#  'Amazon mix',
#  'Trinitario, Forastero',
#  'Forastero (Arriba) ASS',
#  'Criollo, +',
#  'Amazon',
#  'Amazon, ICS',
#  'EET',
#  'Blend-Forastero,Criollo',
#  'Trinitario (Scavina)',
#  'Criollo, Forastero',
#  'Matina',
#  'Forastero(Arriba, CCN)',
#  'Nacional (Arriba)',
#  'Forastero (Arriba) ASSS',
#  'Forastero, Trinitario',
#  'Forastero (Amelonado)',
#  nan,
#  'Trinitario, Nacional',
#  'Trinitario (Amelonado)',
#  'Trinitario, TCGA',
#  'Criollo (Amarru)']

# %%
#plt.xticks(rotation=30, horizontalalignment="center")
plt.figure(figsize=(10,10))
sns.countplot(y='Bean_Type',data=dataset)

# %%
store_count=dict(dataset['Bean_Type'].value_counts())

# %%
for i in Bean_Type[1:]:
     print(i,store_count[i])
# Out:
# Criollo 153
# Trinitario 419
# Forastero (Arriba) 37
# Forastero 87
# Forastero (Nacional) 52
# Criollo, Trinitario 39
# Criollo (Porcelana) 10
# Blend 41
# Trinitario (85% Criollo) 2
# Forastero (Catongo) 2
# Forastero (Parazinho) 8
# Trinitario, Criollo 9
# CCN51 1
# Criollo (Ocumare) 1
# Nacional 2
# Criollo (Ocumare 61) 2
# Criollo (Ocumare 77) 1
# Criollo (Ocumare 67) 1
# Criollo (Wild) 1
# Beniano 3
# Amazon mix 2
# Trinitario, Forastero 2
# Forastero (Arriba) ASS 6
# Criollo, + 1
# Amazon 1
# Amazon, ICS 2
# EET 3
# Blend-Forastero,Criollo 1
# Trinitario (Scavina) 1
# Criollo, Forastero 2
# Matina 3
# Forastero(Arriba, CCN) 1
# Nacional (Arriba) 3
# Forastero (Arriba) ASSS 1
# Forastero, Trinitario 1
# Forastero (Amelonado) 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-fdee7d1f3173> in <module>
#       1 for i in Bean_Type[1:]:
# ...
